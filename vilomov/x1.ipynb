# %%
# работает: переводит и пишет в файл. но нужно доделать не только футбол

# загружаем необходимые модули и библиотеки
import openai
import random
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
from deep_translator import GoogleTranslator

key_words = ['прогноз']
openai.api_key = ("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")

#проверяем доступность сайта
games_meta = ['futbol', 'hokkey', 'basketbol', 'tennis']
games = ['football', 'hockey', 'basketball', 'tennis']
links = []

# for game in games_meta:
#     req = Request(
#         url='https://metaratings.ru/prognozy/' + game,
#         headers={'User-Agent': 'Mozilla/5.0'}
#     )
#     website_url = urlopen(req).read()
#     soup = BeautifulSoup(website_url, 'lxml')
#     soup = soup.find('div', class_='TipsList_TipsList__dDOki')
#     news_link = soup.find_all('div', class_='TipsList_TipsBoxTitle__sCRne')
#     for news in news_link:
#         links.append(
#             {
#                 'link': 'https://metaratings.ru' + news.find('a').get('href'),
#                 'text': news.find('a').get_text()#.lower().replace('«', '').replace('»', '').replace('— ', '')
#             })

for game in games:
    req = Request(
        url='https://odds.ru/' + game + '/forecasts/',
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    website_url = urlopen(req).read()
    soup = BeautifulSoup(website_url, 'lxml')
    news_link = soup.find_all('div', class_='forecasts-post__title')
    for news in news_link:
        links.append(
            {
                'link': 'https://odds.ru' + news.find('a').get('href'),
                'text': news.find('a').get_text()#.lower().replace('«', '').replace('»', '').replace('— ', '')
            })

for game in games:
    req = Request(
        url='https://www.vseprosport.ru/news/' + game,
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    website_url = urlopen(req).read()
    soup = BeautifulSoup(website_url, 'lxml')
    news_link = soup.find_all('a', class_='forecast no-link-text small-text p-10')[:12]
    for news in news_link:
        links.append(
            {
                'link': 'https://www.vseprosport.ru' + news.get('href'),
                'text': news.find('div', class_='forecast__text').get_text()
            })

for game in games:
    req = Request(
        url='https://stavkiprognozy.ru/prognozy/' + game + '/',
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    website_url = urlopen(req).read()
    soup = BeautifulSoup(website_url, 'lxml')
    news_link = soup.find_all('div', class_='box-item-body announce-item-body')
    for news in news_link:
        links.append(
            {
                'link': 'https://stavkiprognozy.ru' + news.find('a').get('href'),
                'text': news.find_next('div', class_='single-announce-team-title').get_text()
            })

req = Request(
    url='https://www.championat.com/news/bets/1.html',
    headers={'User-Agent': 'Mozilla/5.0'}
)
website_url = urlopen(req).read()
soup = BeautifulSoup(website_url, 'lxml')
news_link = soup.find_all('div', class_='news-item')
for news in news_link:
    links.append(
        {
            'link': 'https://www.championat.com' + news.find('a').get('href'),
            'text': news.find('a').get_text()#.lower().replace('«', '').replace('»', '').replace('— ', '')
        })

req = Request(
    url='https://www.liveresult.ru/tips',
    headers={'User-Agent': 'Mozilla/5.0'}
)
website_url = urlopen(req).read()
soup = BeautifulSoup(website_url, 'lxml')
news_link = soup.find_all('div', class_='tips-list-tip')
for news in news_link:
    links.append(
        {
            'link': 'https://www.liveresult.ru' + news.find('a').get('href'),
            'text': news.find('a').get_text().strip().replace('\n', ' - ')
        })

req = Request(
    url='https://stavki-online.info/prognozy-na-matchi/',
    headers={'User-Agent': 'Mozilla/5.0'}
)
website_url = urlopen(req).read()
soup = BeautifulSoup(website_url, 'lxml')
news_link = soup.find_all('h4')[:15]#('div', class_='recent-posts-content')
for news in news_link:
    links.append(
        {
            'link': news.find('a').get('href'),
            'text': news.find('a').get_text()
        })

req = Request(
    url='https://ironbets.ru/prognozy/',
    headers={'User-Agent': 'Mozilla/5.0'}
)
website_url = urlopen(req).read()
soup = BeautifulSoup(website_url, 'lxml')
news_link = soup.find_all('div', class_='post-card__title')
for news in news_link:
    links.append(
        {
            'link': news.find('a').get('href'),
            'text': news.find('a').get_text()
        })

# req = Request(
#     url='https://www.sports.ru/news/',
#     headers={'User-Agent': 'Mozilla/5.0'}
# )
# website_url = urlopen(req).read()
# soup = BeautifulSoup(website_url, 'lxml')
# news_link = soup.find_all('a', class_='short-text')
# for news in news_link[:100]:
#     links.append(
#         {
#             'link': 'https://www.sports.ru' + news.get('href'),
#             'text': news.get_text()#.lower().replace('«', '').replace('»', '').replace('— ', '')
#         })

df1 = pd.DataFrame(links)
df1
# Out:
#                                                   link  \
# 0    https://odds.ru/football/forecasts/prognoz-viz...
# 1    https://odds.ru/football/forecasts/22-y-tur-ch...
# 2    https://odds.ru/football/forecasts/aroka-kasa-...
# 3    https://odds.ru/football/forecasts/prevyu-vene...
# 4    https://odds.ru/football/forecasts/breshiya-ba...
# ..                                                 ...
# 367  https://ironbets.ru/prognozy/football/nantes-j...
# 368  https://ironbets.ru/prognozy/football/chelsea-...
# 369  https://ironbets.ru/prognozy/football/tottenha...
# 370  https://ironbets.ru/prognozy/football/monaco-b...
# 371  https://ironbets.ru/prognozy/football/manchest...
#
#                                                   text
# 0    Прогноз «Визела» - «Бенфика»: матч 22-го тура ...
# 1    22-й тур чемпионата Португалии «Маритиму» - «С...
# 2    «Арока» - «Каса Пиа»: прогноз на матч 22-го ту...
# 3    Превью «Венеция» - «Кальяри»: матч 26-го тура ...
# 4    «Брешия» - «Бари»: превью и прогноз на матч 26...
# ..                                                 ...
# 367  Нант – Ювентус. Сотворят ли «канарейки» сенсацию?
# 368  Челси – Боруссия Д. Возьмут ли Синие реванш за...
# 369  Тоттенхэм – Милан. Смогут ли лондонцы сделать ...
# 370  Монако – Байер. Продолжат ли монегаски побеждать?
# 371  Манчестер Юнайтед – Барселона. Какая команда п...
#
# [372 rows x 2 columns]

# %%
df2 = pd.DataFrame()
key_words = [item.lower() for item in key_words]
df1.text = [item.lower() for item in df1.text]
for line in df1.text:
    if all(word in line for word in key_words):
        df0 = df1[df1.text.str.contains(line)]
        df2 = pd.concat([df2, df0], axis= 0 ).drop_duplicates ()
df2
# Out:
#                                                   link  \
# 0    https://odds.ru/football/forecasts/prognoz-viz...
# 1    https://odds.ru/football/forecasts/22-y-tur-ch...
# 2    https://odds.ru/football/forecasts/aroka-kasa-...
# 4    https://odds.ru/football/forecasts/breshiya-ba...
# 5    https://odds.ru/football/forecasts/prognoz-lec...
# ..                                                 ...
# 340  https://stavki-online.info/monako-bajer-23-2-2...
# 341  https://stavki-online.info/manchester-yunajted...
# 346  https://ironbets.ru/prognozy/mma/ufc/brunson-d...
# 361  https://ironbets.ru/prognozy/boxing/tszyu-harr...
# 362  https://ironbets.ru/prognozy/mma/ufc/shevchenk...
#
#                                                   text
# 0    прогноз «визела» - «бенфика»: матч 22-го тура ...
# 1    22-й тур чемпионата португалии «маритиму» - «с...
# 2    «арока» - «каса пиа»: прогноз на матч 22-го ту...
# 4    «брешия» - «бари»: превью и прогноз на матч 26...
# 5    прогноз «лечче» - «сассуоло»: матч 24-го тура ...
# ..                                                 ...
# 340  монако – байер ⚽ прогноз и ставки на 23 феврал...
# 341  манчестер юнайтед – барселона ⚽ прогноз на 23 ...
# 346    прогноз на бой дерек брансон – дрикус дю плесси
# 361             прогноз на бой тим цзю – тони харрисон
# 362  прогноз на бой валентина шевченко – алекса грассо
#
# [183 rows x 2 columns]

# %%
#проверяем доступность сайта
news = ''
for link in sorted(df2.link,key=lambda _: random.random()):
    a_len = 0
    if len(news) < 4000:
        req = Request(
            url=link,
            headers={'User-Agent': 'Mozilla/5.0'}
        )
        website_url = urlopen(req).read()
        soup = BeautifulSoup(website_url, 'lxml')

        if 'metaratings.ru' in link:
            article_body = soup.find("article", class_=None)
            for p in article_body.find_all("p")[-3:]:
                if p.find("b"):
                    p.extract()
            for td in article_body.find_all('p', class_=None):
                a_len += len(str(td.text))
                if a_len < 3000:
                    news += str(td.text) + ' '
            news += '\n'

        if 'championat.com' in link:
            article_body = soup.find("div", class_="article-content js-content-banners-wrapper js-copyright-content js-loyalty-article-content")
            for p in article_body.find_all("b")[-5:]:
                if p.find("a"):
                    p.extract()
            for td in article_body.find_all('p', class_=None):
                news += str(td.text) + ' '
            news += '\n'

        if 'odds.ru' in link:
            article_inherit = soup.find("div", class_="post-inherit__description").get_text()
            article_body = soup.find("div", class_="forecast-text")
            news += article_inherit.replace('\n', ' ').replace('\t', ' ').replace('   ', '')
            for p in article_body.find_all("b")[-3:]:
                if p.find("a"):
                    p.extract()
            for td in article_body.find_all('p', class_=None):
                news += str(td.text.replace('\n', ' ').replace('«Фонбет»', '')) + ' '
            news += '\n'

        if 'sports.ru' in link:
            article_body = soup.find("div", class_="article__content js-mediator-article")
            for p in article_body.find_all("p")[-3:]:
                if p.find("i"):
                    p.extract()
            for td in article_body.find_all('p', class_=None):
                news += str(td.text) + ' '
            news += '\n'

        if 'liveresult.ru' in link:
            article_body = soup.find("div", class_="tip-page-tex article-text mb-3")
            for td in article_body.find_all('p'):
                news += str(td.text.replace('\xa0', '').replace('\n', ' ')) + ' '
            news += '\n'

        if 'stavki-online.info' in link:
            article_body = soup.find("div", class_="fusion-column-wrapper fusion-column-has-shadow fusion-flex-column-wrapper-legacy")
            for p in article_body.find_all("div", class_="reading-box")[-3:]:
                if p.find('a'):
                    p.extract()
            for td in article_body.find_all('p', class_=None)[:-1]:
                news += str(td.text) + ' '
            news += '\n'

        if 'ironbets.ru' in link:
            article_body = soup.find("div", class_="entry-content")
            for td in article_body.find_all('p'):
                news += str(td.text.replace('Winline', '')) + ' '
            news = news+'\n'

        if 'vseprosport.ru' in link:
            article_body = soup.find("div", class_="white-radius mb-4")
            for td in article_body.find_all('p'):
                news += str(td.text) + '\n '
            news = news+'\n'

        if 'stavkiprognozy.ru' in link:
            article_body = soup.find("div", itemtype="http://schema.org/SportsEvent")
            for td in article_body.find_all('p'):
                news += str(td.text) + '\n '
            news = news+'\n'

print (news)
# Out:
# «Айлендерс» поднялись на седьмую строчку Восточной конференции, хотя на протяжении длительного периода времени находились за пределами зоны плей-офф. Команда в последнее время тоже не отличалась стабильными результатами, но в двух предыдущих встречах праздновала успех.
#  Напомним, что «островитяне» смогли разобраться с «Питтсбургом» (4:2), а также доказали превосходство над «Виннипегом» в равной борьбе со счётом 2:1. Лучше всего для коллектива Ламберта складывается игра, когда он пропускает не больше двух шайб, поскольку сам обычно не демонстрирует высокую результативность.
#  «Лос-Анджелес» остается в числе лидеров Западной конференции и сейчас имеет в своем активе 72 очка. Команда не так давно пребывала в прекрасной форме и шла на серии из четырех викторий. Однако в двух прошлых поединках она потерпела неудачу. Ранее она уступила «Миннесоте» (1:2) и «Нью-Джерси» (3:4 ОТ).
#  Подчеркнем, что «короли» привыкли играть в открытый хоккей и действовать на встречных курсах, поэтому большинство матчей с их участием получаются зрелищными. Главным бомбардиром в составе является Кевин Фиала, который набрал в совокупности 63 балла по системе гол+пас. Судя по всему, трансфером данного форварда менеджмент клуба доволен.
#
# 25 февраля состоится матч 22-го тура чемпионата Португалии «Арока» - «Каса Пиа». Согласно представлениям букмекеров, выше шансы хозяев поля. Давайте попробуем разобраться в предматчевых раскладах.  В преддверии этой встречи «Арока» нашлась предъявить 30 очков: восемь побед, шесть ничьих и семь поражений. Соотношение голов рассыпалось цифрами 24-31. Такие результаты соответствуют седьмой строчке турнирной таблицы. Если рассмотреть домашние встречи этого коллектива, то откроется такая картина: шесть побед, одна ничья и четыре поражения при общей разнице голов 16-15. И так выглядит гостевая статистика «Ароки»: две победы, пять ничьих и три поражения. Забито восемь, пропущено 16.  Нельзя обойти вниманием такой факт: на дистанции последних 24 противостояний «Арока» потерпела только шесть поражений, пять из которых от ТОП-4 португальского футбола: «Браги», «Бенфики, «Спортинга» и «Порту». Плюс я бы отметил, что трех последних противостояниях «Ароки» прошла ставка «ТМ (2,5)». В 21 туре элитного португальского дивизиона «Каса Пиа» добилась весьма впечатляющих следующих результатов: девять побед, пять ничьих и семь поражений при общей разнице голов 18-20. Такое выступление привело команду на шестую позицию чемпионата. Этот коллектив увереннее чувствует себя за периметром домашнего стадиона: пять побед, две ничьих и три поражения. Забито 10, пропущено 12. Это пятый показатель Примейры. И вот так «Каса Пиа» выступает при поддержке своих трибун: четыре победы, три ничьих и четыре поражения при общей разнице голов 8-8.  Можно выделить, что в двух крайних встречах «Каса Пиа» была зафиксирована нулевая ничья. Фаворитом выступает домашняя команда. Вероятность ее победы оценивается в 2,29, в то время как выигрыш гостей котируется в 3,3. На ничью можно устроиться за 3,25.   К вышеизложенному я бы добавил такой штрих: «Каса Пиа» победила только в одной из последних семи игр при четырех поражениях. Приценившись к предложениям букмекеров, я принял решение остановиться на ставке «Ф1 (0)», проход которой котируется в коэффициент 1,64.
# Дата: 1 марта 2023 в 23:00 (МСК) Место игры: Ливерпуль (Англия), стадион «Энфилд» Турнир: Чемпионат Англии. 7 тур из 38 (перенесенный матч). В последних пяти выступлениях Ливерпуль и Вулверхэмптон одержали всего-то по 2 победы, причем одна из викторий коллектива Лопетеги пришлась как раз на встречу с командой Клоппа. Вице-чемпиона Англии «штормит» на текущем отрезке кампании, хотя из лазарета потихоньку возвращаются все основные футболисты. Победами над Эвертоном и Ньюкаслом Ливерпуль приблизился к зоне еврокубков. По потенциальным баллам команда Клоппа занимает 6 строчку, а нестабильный ход Тоттенхэма должен помочь мерсисайдцам с позициями в топ-4 АПЛ. С другой стороны, оплеуха от мадридского Реала в первом поединке 1/8 финала на «Энфилде» может серьезно ударить по моральному состоянию Ливерпуля. В той встрече англичане повели в два гола уже к 14-й минуте, но на 67-й испанцы оформляли пятый кряду гол. Коллектив Анчелотти обнажил все проблемы команды Клоппа, которой не хватает стабильности в центре поля. Традиционное положение команды в середине таблицы Премьер- лиги сменилось отчаянным сражением за выживание. Конечно, Вулверхэмптон располагает большими средствами, но тренерская чехарда влияет на ситуацию клуба. Уверенные победы над Ливерпулем и Саутгемптоном продолжились поражением от прямого конкурента, Борнмута. Сейчас коллектив Лопетеги идет на 15 позиции с 23 баллами – зону вылета и Вулверхэмптон разделяют какие-то 3 пункта. 4 февраля на «Молинью» хозяева вели в счете к 12-й минуте с двумя голами. Ливерпуль больше владел мячом и чаще бил по воротам, но в створ попадали игроки Вулверхэмптона. В концовке точку в поединке поставил точный удар Невеша (3:0). В той февральской игре Вулверхэмптон впервые обыграл Ливерпуль в рамках АПЛ после возвращения в высший английский чемпионат. Теперь же злость и мотивация переполняет подопечных Клоппа, которые настроены взять реванш. Считаем, что поддержка «Энфилда» не оставит Ливерпуль в сложную минуту, а только поведет вперед. Заигрываем выигрыш хозяев у Вулверхэмптона или ТБ 2.5.

# %%
with open('gpt_rewrite_in.txt', 'w', encoding="utf-8") as file:
    for item in news.split('\n'):
        translated_en = GoogleTranslator(source='ru', target='en').translate(item)
        file.write(translated_en + '\n')

with open('gpt_rewrite_in.txt', 'r') as file:
    file_contents = file.read()

with open('gpt_rewrite_prompt.txt', 'r') as file:
    file_prompt = file.read()

content = file_contents.replace('\n', ' ').replace('\t', '').replace('"', '').replace("'", "")\
    .replace('(', '').replace(')', '').replace('  ', ' ').replace('   ', ' ').replace(' .', '.')
results = openai.Completion.create(
    model="text-davinci-003",               # "text-davinci-003" "text-curie-001"
    prompt=file_prompt + content + '.\n',   # make the article in 650 words as sport news:
                                            # make the advertising in 150 words for sporting event:
                                            # summarize text in 600 words:
                                            # shorten the article in 650 words:
    temperature=0.7,
    max_tokens=1500,
    top_p=1,
    best_of=1,
    frequency_penalty=0.5,
    presence_penalty=0,
    stop=["//#"]
)
response = dict(results)
openai_response = response['choices']
eng_text = openai_response[-1]['text']

translated_ru = GoogleTranslator(source='en', target='ru').translate(eng_text)
with open('gpt_rewrite_out.txt', 'w', encoding="utf-8") as file:
    file.write(translated_ru)
