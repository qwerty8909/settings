# %%
# не парсится сама статья нужно доделать

# загружаем необходимые модули и библиотеки
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

#проверяем доступность сайта
req = Request(
    url='https://soccer365.ru/news/',
    headers={'User-Agent': 'Mozilla/5.0'}
)
website_url = urlopen(req).read()
soup = BeautifulSoup(website_url, 'lxml')

links = []
news_link = soup.find_all('div', class_='articles_title')

for news in news_link[:100]:
    links.append(
        {
            'link': news.find('a').get('href'),
            'text': news.find('a').get_text()#.lower().replace('«', '').replace('»', '').replace('— ', '')
        })
df1 = pd.DataFrame(links)
df1
# Out:
#                                 link  \
# 0   https://soccer365.ru/news/16784/
# 1   https://soccer365.ru/news/16783/
# 2   https://soccer365.ru/news/16778/
# 3   https://soccer365.ru/news/16782/
# 4   https://soccer365.ru/news/16779/
# 5   https://soccer365.ru/news/16781/
# 6   https://soccer365.ru/news/16780/
# 7   https://soccer365.ru/news/16777/
# 8   https://soccer365.ru/news/16776/
# 9   https://soccer365.ru/news/16773/
# 10  https://soccer365.ru/news/16775/
# 11  https://soccer365.ru/news/16774/
# 12  https://soccer365.ru/news/16772/
# 13  https://soccer365.ru/news/16771/
# 14  https://soccer365.ru/news/16770/
#
#                                              text
# 0       Атлетико Мадрид ― Атлетик Бильбао: превью
# 1                             ПСЖ — Лилль: превью
# 2                   Фейеноорд – АЗ Алкмар: превью
# 3                     Ньюкасл – Ливерпуль: превью
# 4                       Янг Бойз — Лугано: превью
# 5                    Боруссия М – Бавария: превью
# 6                     Лутон Таун – Бернли: превью
# 7                       Сассуоло – Наполи: превью
# 8   Аль-Наср Эр-Рияд – Аль-Таавон Бурайда: превью
# 9                   АЕК Ларнака — Днепр-1: превью
# 10              Ред Булл Зальцбург – Рома: превью
# 11                    Аякс ― Унион Берлин: превью
# 12                         Ювентус ― Нант: превью
# 13          Барселона ― Манчестер Юнайтед: превью
# 14                          Шахтер – Ренн: превью

# %%
df2 = pd.DataFrame()
key_words = ['Манчестер', 'Лестер']
key_words = [item.lower() for item in key_words]
df1.text = [item.lower() for item in df1.text]
for line in df1.text:
    if all(word in line for word in key_words):
        df0 = df1[df1.text.str.contains(line)]
        df2 = pd.concat([df2, df0], axis= 0 )
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#проверяем доступность сайта
news = ''
text = ''
for link in df2.link:
    req = Request(
        url=link,
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    website_url = urlopen(req).read()
    soup = BeautifulSoup(website_url, 'lxml')

    # Extract the text of the article
    article_body = soup.find("div", class_="news_body")
    print (article_body.get_text())

    # # Check the last p tags for the presence of a tags
    # for p in article_body.find_all("p")[-3:]:
    #     if p.find("i"):
    #         p.extract()
    #
    #     # Concatenate the text content of the remaining p tags
    #     for p in article_body.find_all("p"):
    #         article_text += p.text.strip() + " "
    #         text = title + article_text
    #     text += '\n'
    # # for item in text.split('\n'):
    # #     if len(item.split(' ')) > 10:
    # #         print (item)
    #     print(text)


#     for td in article_body.find_all('p', class_=None):
#         news += str(td.text) + ' '
#     news += '\n'
# for item in news.split('\n'):
#     if len(item.split(' ')) > 100:
#         print (item)
# Out:
# Фото: Soccer365.ru
#
#
#
# 11.78
# X3.94
# 24.98
# ТБ 2.51.90ТМ 2.52.04ОЗ да1.78ОЗ нет1.99 Турнирный путь
#
# Во втором сезоне подряд "Барселона" не сумела преодолеть групповой этап Лиги чемпионов: каталонцы уступили в борьбе с "Баварией" и "Интером". Однако, третье место "сине-гранатовые" заняли без проблем, благодаря чему они и вышли в 1/16 финала Лиги Европы.
#
# А вот "Манчестер Юнайтед" начинал сезон уже в Лиге Европы: "манкунианцы" уступили первое место в группе "Реалу Сосьедад", из-за чего не сумели сразу проскочить в 1/8 финала.
#
# Ключевые моменты
#
# Барселона
#
# 1. После паузы на ЧМ "Барселона" набрала отличный ход, но есть и проблемы
#
# Пауза на чемпионат мира неожиданно благоприятно подействовала на "Барселону", которая после возобновления клубного сезона штампует победу за победой: в 12 матчах у каталонцев одна ничья и 11 викторий. Не заставили себя ждать и турнирные успехи: "Барса" вышла в полуфинал Кубка Испании, оторвалась от "Реала" в чемпионате на восемь очков и обыграла всё тот же "Реал" в финале Суперкубка Испании. Команда обрела уверенность в собственных силах, которую ранее серьёзно поколебала неудача в ЛЧ.
#
# При этом "Барселона" забивает в 16 матчах подряд, а в последних семи встречах она пропустила лишь один гол. Но не всё так идеально, как кажется на первый взгляд. Оборона "блауграны" действительно хороша, но каталонцы на стабильно высоком уровне отыграли лишь матч с "Реалом" в Суперкубке (3:1). В остальных 11 встречах "Барса" играла эпизодами, отдавая инициативу на определённых отрезках матчей даже таким командам, как "Хетафе" и "Жирона". Так что такие шикарные показатели по пропущенным мячам стали возможны во многом благодаря выдающейся игре Марка-Андре тер Штегена на ленточке и индивидуальным перфомансам Рональда Араухо.
#
# 2. Потеря Бускетса и Дембеле сказывается на игре "Барселоны"
#
# Несмотря на длинную скамейку запасных, травмы Серджи Бускетса и Усмана Дембеле серьёзно ударили по "Барселоне". В лице Усмана каталонцы потеряли своего самого креативного и быстрого вингера, который мог бы доставить обороне "МЮ" массу проблем. Но гораздо тяжелее "Барса" переживает потерю Бускетса.
#
# Если Серджи здоров, то он играет всегда, так как альтернативы капитану "Барселоны" в распоряжении Хави нет. И теперь вынужденно из-за травмы Бускетса в опорной зоне с Де Йонгом приходится играть Франку Кессье, который абсолютно не тянет эту роль. Особенно нехватка Бускетса была заметна в недавнем матче "Барселоны" с "Вильярреалом", который не только не прижался к своим воротам, но и забрал мяч (53%:47%), захватив инициативу. С Бускетсом в составе "Барса" в текущем розыгрыше Примеры по владению не уступала никому.
#
# Манчестер Юнайтед
#
# 1. Маркус Рэшфорд очень хорош и тащит атаку "МЮ". Англичанина попробуют нейтрализовать?
#
# После возобновления клубного сезона "Манчестер Юнайтед" ни разу не уходил с поля без забитых мячей, забивая в среднем по 2.1 гола за матч. Причём по два гола "манкунианцы" вонзали в ворота "Арсенала" и "Манчестер Сити" — лидеров АПЛ. Ключевым игроком атаки стал Маркус Рэшфорд, который забил 21 гол (из них 13 голов уже после паузы на ЧМ) и сделал семь ассистов в 34-х матчах сезона. Маркус и тащит мяч, и открывается, и завершает — в атаке он вообще везде.
#
# Очевидно, что реактивный Рэшфорд крайне опасен для "Барселоны", которая играет с высокой линией обороны. Если "МЮ" решит сыграть с каталонцами вторым номером, используя контратаки в качестве главного оружия, то Маркус с его скоростью будет ещё более опасен.
#
# Однако, в распоряжении Хави есть средство для сдерживания быстрых нападающих — это Рональд Араухо. В двух из трёх последних матчей между "Барселоной" и "Реалом"  Араухо был на поле и играл персонально по Винисиусу Жуниору. Обе встречи "Барса" выиграла, а Винисиус не сделал ни одного результативного действия. Вполне вероятно, что и за Рэшфордом Араухо будет наблюдать с удвоенным вниманием — по крайней мере, испанская пресса уже сообщала о такой задумке Хави.
#
# 2. Лисандро Мартинес, Кристиан Эриксен и ещё пять игроков "Манчестер Юнайтед" пропустят матч с "Барсой"
#
# Кадровых проблем у "Юнайтед" предостаточно, причём не все они связаны с травмами: Лисандро Мартинес и Марсель Забитцер пропустят встречу с "Барсой" из-за перебора жёлтых карточек. Особенно неприятна потеря Мартинеса, который с первых же матчей в "МЮ" стал одним из лидеров защиты и железным игроком основы.
#
# Из-за травм не сыграют Кристиан Эриксен, Донни Ван де Бек, Скотт Мактоминей, Антони Марсьяль и Антони. Главной проблемой станет отсутствие Эриксена — его будет очень не хватать при выходе из под прессинга, которым "Барса" англичан наверняка постарается придавить. К тому же, Эриксен ещё и третий в команде по системе "гол+пас".
#
# Потеря остальных четверых игроков не столь фатальна, однако ротировать состав Эрику тен Хагу будет гораздо сложнее. А ротировать нужно: "Юнайтед" играет по два матча в неделю, поэтому во втором тайме придётся освежать игру заменами.
#
# Составы и тактика
#
# 4-4-24-2-3-11тер Стеген18Альба15Кристенсен23Кунде4Араухо19Кессье21де Йонг6Гави8Педри9Левандовски22Рафинья1Де Хеа20Далот5Магуайр19Варан23Шоу18Каземиро17Фред25Санчо8Фернандеш10Рэшфорд27Вегорст
#
# "Барселона" окончательно перешла на схему с четвёркой полузащитников, которую мы и увидим в матче с "МЮ". В составе, скорее всего, будет минимум изменений: Алехандро Бальде вряд ли выйдет в старте, так как Жорди Альба более опытный футболист, да к тому же он в игре с "Вильярреалом" получил отдых. Травмированных Дембеле и Бускетса заменят Рафинья и Кессье, как было и в прошлом матче.
#
# А вот тен Хаг предпочитает схему 4-2-3-1, тут сюрпризов ждать не стоит. Дисквалифицированного Лисандро Мартинеса в центре обороны заменит Харри Магуайр, а вместо травмированного Кристиана Эриксена на поле появится Фред.
#
# Статистика последних десяти матчей
#
#
#
# Ставки на тренд
#
# В трёх из последних пяти матчей с участием "Манчестер Юнайтед" забивали обе команды. Ставка: обе забьют — Да за 1.75.
#
# В последних десяти матчах "Барселона" забивала первой. Ставка: кто забьёт первый гол — К1 за 1.60.
#
# Прогноз Soccer365.ru
#
# БарселонаvsМанчестер Юнайтед16.02.2023 18:45"Барселона" набрала шикарную форму: после камбэка клубного сезона каталонцы ни разу не проиграли и одержали 11 побед в 12 матчах, а в последних семи встречах они пропустили всего один гол. "Блауграна" проводит лучший отрезок в сезоне, она обрела уверенность и с прекрасным настроем подходит к игре с "МЮ". Однако, без травмированных Серджи Бускетса и Усмана Дембеле каталонцам намного сложнее добиваться результата: и Усман, и Серджи — одни из основополагающий игроков в системе Хави. Похожая ситуация и у "Манчестер Юнайтед, который также набрал неплохой ход: после перерыва на ЧМ "манкунианцы" проиграли всего раз и забивают в среднем по 2.1 гола за матч. Особенно хорош Маркус Рэшфорд, который в текущем сезоне наколотил уже 21 гол. Однако, кадровые проблемы у "МЮ" ещё более серьёзные: Лисандро Мартинес и Марсель Забитцев не сыграют с "Барсой" из-за дисквалификаций, а вот Кристиан Эриксен, Антони, Антони Марсьяль и Скотт Мактоминей — из-за повреждений.  Учитывая кадровые потери "МЮ", а также тот факт, что матч пройдёт на "Камп Ноу", где в этом сезоне "Барса" проигрывала лишь "Баварии", предположим, что каталонцы в упорной борьбе одержат победу.Прогноз: 2-1
#
#
# 11.78
# X3.94
# 24.98
# ТБ 2.51.90ТМ 2.52.04ОЗ да1.78ОЗ нет1.99
#
#
#
#
#
#
#
# 13.26
# X3.46
# 22.30
# ТБ 2.51.88ТМ 2.52.02ОЗ да1.66ОЗ нет2.23 Турнирное положение
#
# Очная встреча двух лидеров Английской Премьер-лиги. "Арсенал" лидирует в таблице, имея на своем счету 51 очко. "Манчестер Сити" отстает на три очка (48).
#
# На минувших выходных "Арсенал" сыграл вничью с "Брентфордом" (1:1), а "Манчестер Сити" превзошел "Астон Виллу" (3:1).
#
# Ключевые моменты
#
# Арсенал
#
# 1. Лидирующий в АПЛ "Арсенал" набрал всего одно очко в трех последних матчах
#
# Серия неудач символично началась с поражения от "Сити" в Кубке Англии. До этого у "Арсенала" было шесть побед и одна ничья с "Ньюкаслом". Проигрывали они последний раз и вовсе 4 сентября — против "Манчестер Юнайтед". В двух же последних турах АПЛ у "канониров" — поражение от "Эвертона" со дна таблицы и домашняя ничья с "Брентфордом".
#
# В первом случае "Арсеналу" попался самый сильный и заведенный "Эвертон" в текущем сезоне — это был первый матч нового главного тренера "ирисок" Шона Дайча, который перекрыл команде Артеты весь кислород (его подопечные сыграли невероятно дисциплинированно и строго). "Брентфорд" — априори неудобнейший соперник для всех признанных топов АПЛ. Не такая суровая команда, как "Эвертон" Дайча, но с массой своих плюсов и преимуществ. Сыграли с "канонирами" вничью, но могли и обыгрывать их.
#
# Таким образом, "Арсенал" подходит к важнейшему с турнирной точки зрения матчу с целой серией (первой в текущем сезоне) неудач. Оптимизма может внушать то, что "Манчестер Сити" вряд ли будет действовать в стиле "Брентфорда", и тем более "Эвертона". И тогда у "канониров" могут быть шансы.
#
# 2. Первый выход Троссарда в стартовом составе вместо Мартинелли должен улучшить игру "Арсенала"
#
# Левый бразильский вингер "Арсенала" Мартинелли — самый критикуемый футболист команды последних недель. Все соперники уже научились играть против Габриела, в арсенале у которого имеется не так много приемов и навыков. Тот же Сака на противоположном фланге обыгрывает своих оппонентов в разных ситуациях и условиях.
#
# Возможно, Артета давно понял однобокость бразильца, и поэтому так хотел Мудрика. Украинца, как известно, подписать не получилось. Но перешел Троссард, удачно проявляющий себя, выходя во вторых таймах игр вместо Мартинелли. В предыдущем матче с "Брентфордом" бельгиец отметился дебютным голом за "Арсенал". Леандро явно превосходит Габриела в разнообразии и своей новизне в структуре "канониров".
#
# Выход Троссарда в стартовом составе против "Сити" может стать необходимым катализатором и решающим фактором в данном противостоянии.
#
# Манчестер Сити
#
# 1. "Манчестер Сити" после справедливого поражения от "Тоттенхэма" уверенно обыграл "Астон Виллу" и произвел мощное впечатление
#
# Все это время после перерыва на чемпионат мира "Манчестер Сити" провел лишь пару уверенных матчей с однозначным доминированием. И в минувшее воскресенье случился третий — "Сити" четко, быстро и интенсивно разобрался с "Астон Виллой" уже в первом тайме. Хотя за неделю до этого "горожане" по всем статьям проиграли "Тоттенхэму".
#
# Индивидуально впечатлил Родри, забивший уже на четвертой минуте. У испанского опорника впечатляющие цифры: 116 касаний мяча, три удара (два в створ), четыре ключевых паса, 90.3% точность передач, пять выигранных воздушных дуэлей. Общая статистика: 67% владения мячом, 17 голевых моментов, девять ударов в створ против двух, а также шесть спасений от аргентинского голкипера соперника Эмилиано Мартинеса.
#
# Холанд снова не впечатлил, Силва пробовался на новой для себя позиции, но при всем этом "горожане" были хороши — это не очень добрый сигнал для "Арсенала". Но стоит отметить, что в плане двух последних соперников подопечным Гвардиолы повезло больше. "Тоттенхэм" команда Артеты недавно обыгрывала, а "Астон Вилла" не играет настолько плотно и организованно, как "Эвертон" с "Брентфордом".
#
# 2. "Манчестер Сити" обыгрывал "Арсенал" пару недель назад в Кубке Англии, но в чемпионате ожидается совсем иной матч
#
# Эти команды уже встречались друг с другом 27 января 2023 года. "Манчестер Сити" принимал "Арсенал" на своем поле в 1/16 финала Кубка Англии. Тогда все решил единственный забитый мяч Аке, но та встреча вряд ли будет иметь что-то общее с текущей игрой.
#
# Если Гвардиола в Кубке выставил основной состав, то Артета сделал несколько заметных изменений в стартовом составе. Основные футболисты начали выходить на поле, но уже во втором тайме. По самому матчу было заметно, что оба тренера действуют не на полную катушку, явно пряча все козыри, задумки и особые подстройки под соперника на скорую встречу в чемпионате. "Арсенал" без особого сожаления расстался с лишним турниром, в очередной раз показав сосредоточенность на АПЛ.
#
# Правда, на данный момент между командами уже три очка, а если "Сити" выиграет и сейчас — они сравняются. И тогда ради чего все это было…
#
# Составы и тактика
#
# 4-3-33-2-4-11Рамздейл35Зинченко6Габриэл12Салиба4Уайт34Джака5Парти8Эдегор19Троссард14Нкетиа7Сака31Мораес2Уокер3Диаш14Ляпорт16Эрнандес8Гюндоган26Марез17де Брёйне19Альварес10Грилиш9Холанд
#
# "Арсенал" играет по схеме 4-3-3. Эль-Ненни, Смит-Роу, Нельсон и Жезус травмированы, остальные — в строю. Состав и тактика команды Артеты — одни из самых стабильных во всей АПЛ. Но в настолько важном матче будет логичен выход Троссарда вместо сбавившего Мартинелли.
#
# "Манчестер Сити" в последних играх использует гибридную схему 3-2-4-1. Наконец вернулся в стартовый состав Диаш. Недоступными остаются Стоунс и Менди. Холанд был заменен в перерыве предыдущего матча, но к игре с "Арсеналом" готовится вместе со всей командой.
#
# Статистика последних десяти матчей
#
#
#
# Ставки на тренд
#
# "Арсенал" не проигрывает в 14-ти из 15-ти последних матчей АПЛ. 1X за 1.61.
#
# "Арсенал" забивает и пропускает дома в 12-ти из 14-ти последних матчей АПЛ. "ОЗ — да" за 1.65.
#
# Прогноз Soccer365.ru
#
# АрсеналvsМанчестер Сити15.02.2023 20:30Еще в конце января, после победы "Манчестер Сити" над "Арсеналом" в Кубке Англии, фаворитизм "канониров" в рамках АПЛ ощущался явно. Многие утверждали, что матч в чемпионате 15 февраля будет совершенно другим, что там у команды Артеты будут шансы. Но последние результаты "Арсенала" на фоне уверенной победы "Сити" над "Астон Виллой" навевают сомнения. Уже три матча "канониры" не побеждают, и всего один мяч забили в этих играх. Команда не так бежит в последнее время — это проблема, над которой Артете нужно работать. Скорее всего, "Арсенал" не будет форсировать события в этой встрече, а постарается сдержать соперника, играя вторым номером. Первым номером уже наигрались с "Эвертоном" и "Брентфордом". "Сити" ничего сверхъестественного не демонстрирует, но добивается результата в последнее время — четыре победы в пяти последних матчах. В плане результата спрогнозируем ничью. "Арсенал" сейчас не так силен, но играет дома, где поражение от прямого конкурента и упущенное первое место станет бедствием. 13.26X3.4622.30ТБ 2.51.88ТМ 2.52.02ОЗ да1.66ОЗ нет2.23Прогноз: 1-1
#
#
# 13.26
# X3.46
# 22.30
# ТБ 2.51.88ТМ 2.52.02ОЗ да1.66ОЗ нет2.23
